# %%
#connect with 9722 drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone "https://github.com/arbab97/WSYCUHK_FDIA"
# Out:
# Cloning into 'WSYCUHK_FDIA'...
# remote: Enumerating objects: 578, done.
# remote: Counting objects: 100% (295/295), done.
# remote: Compressing objects: 100% (228/228), done.
# remote: Total 578 (delta 177), reused 117 (delta 61), pack-reused 283
# Receiving objects: 100% (578/578), 117.80 MiB | 20.90 MiB/s, done.
# Resolving deltas: 100% (329/329), done.

# %%
# %cd "/content/WSYCUHK_FDIA"
# Out:
# /content/WSYCUHK_FDIA

# %% [markdown]
# #TradeOff Analysis

# %%
# %%bash
# python /content/WSYCUHK_FDIA/Code/commulate_results.py
# Out:
#  Saved  ----------------------> MLP 1 64
#  Saved  ----------------------> MLP 1 128
#  Saved  ----------------------> MLP 1 256
#  Saved  ----------------------> MLP 2 64
#  Saved  ----------------------> MLP 2 128
#  Saved  ----------------------> MLP 2 256
#  Saved  ----------------------> MLP 4 64
#  Saved  ----------------------> MLP 4 128
#  Saved  ----------------------> MLP 4 256
#  Saved  ----------------------> CNN 1 64
#  Saved  ----------------------> CNN 1 128
#  Saved  ----------------------> CNN 1 256
#  Saved  ----------------------> CNN 2 64
#  Saved  ----------------------> CNN 2 128
#  Saved  ----------------------> CNN 2 256
#  Saved  ----------------------> CNN 4 64
#  Saved  ----------------------> CNN 4 128
#  Saved  ----------------------> CNN 4 256
#  Saved  ----------------------> LSTM 1 64
#  Saved  ----------------------> LSTM 1 128
#  Saved  ----------------------> LSTM 1 256
#  Saved  ----------------------> LSTM 2 64
# ...

# %% [markdown]
# #Variant Analysis

# %%
# %%bash
# python /content/WSYCUHK_FDIA/Code/commulate_results_for_variants.py
# Out:
#  Saved  ----------------------> 1 MLP 2 128
#  Saved  ----------------------> 1 CNN 2 128
#  Saved  ----------------------> 1 LSTM 2 128
#  Saved  ----------------------> 1 cnn-lstm-paper-experiments 2 128
#  Saved  ----------------------> 2 MLP 2 128
#  Saved  ----------------------> 2 CNN 2 128
#  Saved  ----------------------> 2 LSTM 2 128
#  Saved  ----------------------> 2 cnn-lstm-paper-experiments 2 128
#  Saved  ----------------------> 3 MLP 2 128
#  Saved  ----------------------> 3 CNN 2 128
#  Saved  ----------------------> 3 LSTM 2 128
#  Saved  ----------------------> 3 cnn-lstm-paper-experiments 2 128
#  Saved  ----------------------> 4 MLP 2 128
#  Saved  ----------------------> 4 CNN 2 128
#  Saved  ----------------------> 4 LSTM 2 128
#  Saved  ----------------------> 4 cnn-lstm-paper-experiments 2 128
#  Saved  ----------------------> 5 MLP 2 128
#  Saved  ----------------------> 5 CNN 2 128
#  Saved  ----------------------> 5 LSTM 2 128
# ...

# %% [markdown]
# #Main Results from 2 Layers, 128 Neurons

# %%
# %%bash
# python /content/WSYCUHK_FDIA/Code/commulate_results_main_models.py
# Out:
#  Saved  ----------------------> MLP 2 128
#  Saved  ----------------------> CNN 2 128
#  Saved  ----------------------> LSTM 2 128
#  Saved  ----------------------> Attention 2 128
#  Saved  ----------------------> cnn-lstm-paper-experiments 2 128
# Done
