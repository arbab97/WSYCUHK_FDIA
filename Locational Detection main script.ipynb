# %% [markdown]
# #Connect to Drive

# %%
#

# %%
# !nvidia-smi
# Out:
# Wed Dec  1 21:39:22 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P8    34W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#connect with 9722 drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ## In order to copy file from google drive into the current session. 
# !cp '/content/drive/MyDrive/thesisdata/whole dataset/labelled data/spectrograms_vmin_vmax_highpass_balance_top5_2_cropped.zip' 'spectrograms_vmin_vmax_highpass_balance_top5_2_cropped.zip'
# !unzip 'spectrograms_vmin_vmax_highpass_balance_top5_2_cropped.zip'

# %% [markdown]
# #Setting up the environment

# %%
# %%capture
# %%bash
MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
MINICONDA_PREFIX=/usr/local
wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
chmod +x $MINICONDA_INSTALLER_SCRIPT
./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX

# %%
# %%capture
# %%bash
conda install --channel defaults conda python=3.6 --yes
conda update --channel defaults --all --yes

# %% [markdown]
# #importing code

# %%
# %cd '/content'
# Out:
# /content

# %%
# !git clone "https://github.com/arbab97/WSYCUHK_FDIA"
# Out:
# Cloning into 'WSYCUHK_FDIA'...
# remote: Enumerating objects: 569, done.
# remote: Counting objects: 100% (286/286), done.
# remote: Compressing objects: 100% (225/225), done.
# remote: Total 569 (delta 170), reused 107 (delta 55), pack-reused 283
# Receiving objects: 100% (569/569), 117.80 MiB | 24.14 MiB/s, done.
# Resolving deltas: 100% (322/322), done.

# %% [markdown]
# #Getting the Training Data

# %% [markdown]
# The following code directly downloads the data from the given file. Execute one of the below (to perform either behavioral or specie class clustering) and comment the other.

# %%
# #14 1 dataset
# %cd '/content'
# !gdown https://drive.google.com/uc?id=1M-rxbB3K1EPmRSwlGQmOf7hHUUp_H46g --output data14_traintest.mat

# %%
# #118 1 dataset
# %cd '/content'
# !gdown https://drive.google.com/uc?id=1qlT4LCW7yOwbsKHbtM1m-iKOPrIsLb85 --output data118_traintest.mat

# %% [markdown]
# #Setting up the environment

# %%
# %cd "/content/WSYCUHK_FDIA"
# Out:
# /content/WSYCUHK_FDIA

# %%
# !conda config --set restore_free_channel true

# %%
# !conda env create -f gpu.yml
# Out:
# done
# done
#
# ...
# seaborn-base-0.11.0  | 215 KB    | : 100% 1.0/1 [00:00<00:00,  5.19it/s]
# google-pasta-0.2.0   | 44 KB     | : 100% 1.0/1 [00:00<00:00, 15.86it/s]
# blinker-1.4          | 21 KB     | : 100% 1.0/1 [00:00<00:00, 15.06it/s]
# torchvision-0.5.0    | 9.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.70s/it]
# joblib-0.17.0        | 205 KB    | : 100% 1.0/1 [00:00<00:00,  9.39it/s]
# pyqt-5.9.2           | 5.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
# tensorflow-estimator | 272 KB    | : 100% 1.0/1 [00:00<00:00,  5.97it/s]
# gettext-0.19.8.1     | 3.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.19it/s]
# oauthlib-3.1.0       | 88 KB     | : 100% 1.0/1 [00:00<00:00, 14.74it/s]
# scikit-learn-0.23.2  | 6.9 MB    | : 100% 1.0/1 [00:01<00:00,  1.49s/it]
# lz4-c-1.9.2          | 253 KB    | : 100% 1.0/1 [00:00<00:00,  7.25it/s]
# expat-2.2.9          | 196 KB    | : 100% 1.0/1 [00:00<00:00, 14.30it/s]
# xz-5.2.5             | 438 KB    | : 100% 1.0/1 [00:00<00:00,  5.83it/s]
# ...

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# gpu                      /usr/local/envs/gpu

# %% [markdown]
# ##(Instruction) Set the shape inside all_models.py to 19 or 180 for IEEE-14 or IEEE-118 respectively

# %% [markdown]
# #1. Invidual Models for testing Purposes only. (Start from 2. Tradeoff Analysis)

# %% [markdown]
# ##MLP

# %%
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "MLP" --n_epoch 50 --data_dir "/content/data118_traintest.mat" --output_dir "/content/drive/MyDrive/openUAE/locational detection/results_8_nov_IEEE118_3/"

# %% [markdown]
# ##CNN

# %%
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "CNN" --n_epoch 50 --data_dir "/content/data118_traintest.mat" --output_dir "/content/drive/MyDrive/openUAE/locational detection/results_8_nov_IEEE118_3/"

# %% [markdown]
# ##LSTM

# %%
#Change LSTM layer to CuDNNLSTM
# %tensorflow_version 1.x # !!!!!!!!!!!CHANGE THIS because code has been updated at tradeoff analyssi . Now, its not requried to specify the tensorflow version. 
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "LSTM" --n_epoch 50 --data_dir "/content/data118_traintest.mat" --output_dir "/content/drive/MyDrive/openUAE/locational detection/results_8_nov_IEEE118_3/"

# %% [markdown]
# ##Attention model on Bidirectional LSTM

# %%
#Change LSTM layer to CuDNNLSTM
# %tensorflow_version 1.x
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "Attention" --n_epoch 50 --data_dir "/content/data118_traintest.mat" --output_dir "/content/drive/MyDrive/openUAE/locational detection/results_8_nov_IEEE118_3/"

# %% [markdown]
# ## CNN-LSTM

# %%
#Change LSTM layer to CuDNNLSTM
# %tensorflow_version 1.x


# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "cnn-lstm" --n_epoch 50 --data_dir "/content/drive/MyDrive/openUAE/locational detection/data_ieee14_118_locational_detection/data14_1.mat" --output_dir "/content/drive/MyDrive/openUAE/locational detection/results_8_nov_IEEE14_1/"

# %%
#Change LSTM layer to CuDNNLSTM
# %tensorflow_version 1.x
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "cnn-lstm" --n_epoch 50 --data_dir "/content/drive/MyDrive/openUAE/locational detection/data_ieee14_118_locational_detection/data118_1.mat" --output_dir "/content/drive/MyDrive/openUAE/locational detection/results_3_nov_IEEE118_1/"

# %% [markdown]
# # 2. TRADEOFF ANALYSIS

# %% [markdown]
# ##IEEE-14

# %%
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# 70000/70000 [==============================] - 4s 51us/step - loss: 0.0723 - accuracy: 0.9765 - row_accuracy: 0.7126 - val_loss: 0.0642 - val_accuracy: 0.9796 - val_row_accuracy: 0.7442
# Epoch 10/50
# 70000/70000 [==============================] - 4s 52us/step - loss: 0.0717 - accuracy: 0.9766 - row_accuracy: 0.7131 - val_loss: 0.0634 - val_accuracy: 0.9801 - val_row_accuracy: 0.7502
# Epoch 11/50
# 70000/70000 [==============================] - 4s 53us/step - loss: 0.0712 - accuracy: 0.9767 - row_accuracy: 0.7146 - val_loss: 0.0634 - val_accuracy: 0.9809 - val_row_accuracy: 0.7625
# Epoch 12/50
# 70000/70000 [==============================] - 3s 48us/step - loss: 0.0706 - accuracy: 0.9769 - row_accuracy: 0.7155 - val_loss: 0.0621 - val_accuracy: 0.9800 - val_row_accuracy: 0.7454
# Epoch 13/50
# ...

# %%
#IEEE-14 run 2
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#IEEE-14 run 3
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %% [markdown]
# ##IEEE-118

# %%
# good #

# %%
#Run 13
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#Run 12
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#Run 10+11
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#Run 1
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# Running on Colab -------------
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# ...

# %%
#Run 2 RUNNING WITHOUT ATTENTION MODEL
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#RUN 3
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#RUN 4
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#RUN 5
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#RUN 6
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#RUN 7
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#RUN 8
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
#RUN 9
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_models.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_models.sh
# Out:
# TensorFlow 1.x selected.
#  Training ---------------------->  MLP 1 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 128   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 1 256   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
#  Training ---------------------->  MLP 2 64   <----------------------------------------
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  50
# ------------------>>Model Already Exist<<--------------------
# ...

# %%
fdfdfddfdf VJd dfdd HGJHjkbn kk xc

# %% [markdown]
# #3. L2-Norm Variation

# %% [markdown]
# ##IEEE-14

# %%
#Run 1
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_variants.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_variants.sh

# %%
#Run 2
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_variants.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_variants.sh

# %%
#Run 3
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_variants.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_variants.sh

# %%
#Run 4
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_variants.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_variants.sh

# %% [markdown]
# ##IEEE-118

# %%
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_variants.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_variants.sh

# %%
#Run 2
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_variants.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_variants.sh

# %%
#Run 3
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_variants.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_variants.sh

# %%
#Run 4
# %tensorflow_version 1.x
# !chmod +x /content/WSYCUHK_FDIA/Code/run_all_variants.sh 
# !/content/WSYCUHK_FDIA/Code/run_all_variants.sh

# %% [markdown]
# #4. Models Summary (Just for checking the number of parameters of each model)

# %%
# Line 245
# #Printing model details
# model.summary()
# exit()
# # Train, evaluate, predict

# %%
# MLP
# %tensorflow_version 1.x
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "MLP" --n_epoch 0 \
--data_dir "/content/drive/MyDrive/openUAE/locational detection/data_ieee14_118_locational_detection/data118_1.mat" \
--output_dir "/content/drive/MyDrive/openUAE/locational detection/tradeoff_analysis/IEEE118/INVALID SAVE ADDRESS" \
--layers 2 \
--neurons 128 \
--shape 180
# Out:
# Using TensorFlow backend.
# You've selected:  MLP
# With Number of Epochs:  0
# Running on Colab -------------
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# ...

# %%
#CNN
# %tensorflow_version 1.x
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "CNN" --n_epoch 0 \
--data_dir "/content/drive/MyDrive/openUAE/locational detection/data_ieee14_118_locational_detection/data118_1.mat" \
--output_dir "/content/drive/MyDrive/openUAE/locational detection/tradeoff_analysis/IEEE118/INVALID SAVE ADDRESS" \
--layers 2 \
--neurons 128 \
--shape 180
# Out:
# Using TensorFlow backend.
# You've selected:  CNN
# With Number of Epochs:  0
# Running on Colab -------------
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# ...

# %%
#LSTM
# %tensorflow_version 1.x
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "LSTM" --n_epoch 0 \
--data_dir "/content/drive/MyDrive/openUAE/locational detection/data_ieee14_118_locational_detection/data118_1.mat" \
--output_dir "/content/drive/MyDrive/openUAE/locational detection/tradeoff_analysis/IEEE118/INVALID SAVE ADDRESS" \
--layers 2 \
--neurons 128 \
--shape 180
# Out:
# Using TensorFlow backend.
# You've selected:  LSTM
# With Number of Epochs:  0
# Running on Colab -------------
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# ...

# %%
# %tensorflow_version 1.x #ATTENTION
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "Attention" --n_epoch 0 \
--data_dir "/content/drive/MyDrive/openUAE/locational detection/data_ieee14_118_locational_detection/data118_1.mat" \
--output_dir "/content/drive/MyDrive/openUAE/locational detection/tradeoff_analysis/IEEE118/INVALID SAVE ADDRESS" \
--layers 2 \
--neurons 128 \
--shape 180
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x #ATTENTION`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# You've selected:  Attention
# With Number of Epochs:  0
# Running on Colab -------------
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# ...

# %%
#CNN-LSTM
# %tensorflow_version 1.x
# !export CUDA_VISIBLE_DEVICES=0 && source activate gpu && python /content/WSYCUHK_FDIA/Code/all_models.py  --model "cnn-lstm-paper-experiments" --n_epoch 0 \
--data_dir "/content/drive/MyDrive/openUAE/locational detection/data_ieee14_118_locational_detection/data118_1.mat" \
--output_dir "/content/drive/MyDrive/openUAE/locational detection/tradeoff_analysis/IEEE118/INVALID SAVE ADDRESS" \
--layers 2 \
--neurons 128 \
--shape 180
# Out:
# Using TensorFlow backend.
# You've selected:  cnn-lstm-paper-experiments
# With Number of Epochs:  0
# Running on Colab -------------
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# ...

# %% [markdown]
# ## (Instruction) Next Step: Go to Misc. Calculations.ipynb to generate tables from the above experiments
